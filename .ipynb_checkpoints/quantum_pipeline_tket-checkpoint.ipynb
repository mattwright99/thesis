# %% [markdown]
# # Quantum pipeline using t|ket> backend
# This performs a shots-based simulation.

# %%
import numpy as np

def read_data(filename):
    labels, sentences = [], []
    with open(filename) as f:
        for line in f:
            labels.append([1, 0] if line[0] == '1' else [0, 1])
            sentences.append(line[1:].strip())
    return np.array(labels), sentences


train_labels, train_data = read_data('data/mc_train_data.txt')
# dev_labels, dev_data = read_data('data/mc_dev_data.txt')
test_labels, test_data = read_data('data/mc_test_data.txt')

# %% [markdown]
# ### Create diagrams

# %%
from lambeq.ccg2discocat import DepCCGParser

reader = DepCCGParser(possible_root_cats=['S[dcl]'])

raw_train_diagrams = reader.sentences2diagrams(train_data)
# raw_dev_diagrams = reader.sentences2diagrams(dev_data)
raw_test_diagrams = reader.sentences2diagrams(test_data)

# %%
from discopy.rigid import Id


def remove_cups(diagram):
    # Remove cups to reduce post-selection in the circuit, for faster execution

    diags = []
    for box, offset in zip(diagram.boxes, diagram.offsets):
        if not box.dom:  # word box
            diags.insert(offset, box)
        else:  # cup (the only other type of box in these diagrams)
            i = 0
            off = offset
            while off != len(diags[i].cod) - 1:
                assert off > 0
                off -= len(diags[i].cod)
                i += 1
            left, right = diags[i:i+2]
            
            if len(left.cod) == 1:
                new_diag = right >> (left.r.dagger() @ Id(right.cod[1:]))
            else:
                assert len(right.cod) == 1
                new_diag = left >> (Id(left.cod[:-1]) @ right.l.dagger())

            diags[i:i+2] = [new_diag]

    assert len(diags) == 1
    return diags[0]


train_diagrams = [remove_cups(diagram) for diagram in raw_train_diagrams]
# dev_diagrams = [remove_cups(diagram) for diagram in raw_dev_diagrams]
test_diagrams = [remove_cups(diagram) for diagram in raw_test_diagrams]

train_diagrams[0].draw()

# %% [markdown]
# ### Create circuits

# %%
from lambeq.circuit import IQPAnsatz
from lambeq.core.types import AtomicType

ansatz = IQPAnsatz({AtomicType.NOUN: 1, AtomicType.SENTENCE: 1},
                   n_layers=1, n_single_qubit_params=3)

train_circuits = [ansatz(diagram) for diagram in train_diagrams]
# dev_circuits =  [ansatz(diagram) for diagram in dev_diagrams]
test_circuits = [ansatz(diagram) for diagram in test_diagrams]

train_circuits[0].draw(figsize=(9, 12))

# %% [markdown]
# ### Parameterise

# %%
from sympy import default_sort_key

# all_circuits = train_circuits + dev_circuits + test_circuits
all_circuits = train_circuits + test_circuits

# sort the symbols since they are returned as a set
parameters = sorted(
    {s for circ in all_circuits for s in circ.free_symbols},
    key=default_sort_key)

# %%
## CONFIGURE BACKEND
# This uses Qiskit, which requires installing `pytket-qiskit`.
# For more information on how to use pytket with different backends, see:
# https://cqcl.github.io/pytket/build/html/extensions/

# Aer is a shots-based backend that is always available.

from pytket.extensions.qiskit import AerBackend
backend = AerBackend()

## Having an IBMQ account gives access to the IBM emulator for noisy simulations:
#
# from pytket.extensions.qiskit import IBMQEmulatorBackend
# backend = IBMQEmulatorBackend('PLACEHOLDER')
#
## To use a real device:
#
# from pytket.extensions.qiskit import IBMQBackend
# backend = IBMQBackend('PLACEHOLDER')

backend_config = {
    'backend': backend,
    'compilation': backend.default_compilation_pass(2),
    'n_shots': 2**13  # maximum recommended shots, reduces sampling error
}

# %%
from discopy.quantum import Circuit, Id, Measure


def randint(rng, low=-1 << 63, high=1 << 63-1):
    return rng.integers(low, high)


def normalise(predictions):
    # apply smoothing to predictions
    predictions = np.abs(predictions) + 1e-9
    return predictions / predictions.sum()


def make_pred_fn(circuits, rng):
    measured_circuits = [c >> Id().tensor(*[Measure()] * len(c.cod)) for c in circuits]
    circuit_fns = [c.lambdify(*parameters) for c in measured_circuits]

    def predict(params):
        outputs = Circuit.eval(*(c_fn(*params) for c_fn in circuit_fns),
                               **backend_config, seed=randint(rng))
        return np.array([normalise(output.array) for output in outputs])
    return predict


SEED = 0
rng = np.random.default_rng(SEED)

train_pred_fn = make_pred_fn(train_circuits, rng)
# # dev_pred_fn = make_pred_fn(dev_circuits, rng)
test_pred_fn = make_pred_fn(test_circuits, rng)

# %% [markdown]
# ### Train

# %%
from noisyopt import minimizeSPSA

def make_cost_fn(pred_fn, labels):
    def cost_fn(params, **kwargs):
        predictions = pred_fn(params)

        cost = -np.sum(labels * np.log(predictions)) / len(labels)  # binary cross-entropy loss
        costs.append(cost)

        acc = np.sum(np.round(predictions) == labels) / len(labels) / 2  # half due to double-counting
        accuracies.append(acc)

        return cost

    costs, accuracies = [], []
    return cost_fn, costs, accuracies


train_cost_fn, train_costs, train_accs = make_cost_fn(train_pred_fn, train_labels)
# # dev_cost_fn, dev_costs, dev_accs = make_cost_fn(dev_pred_fn, dev_labels)

# x0 = np.array(rng.random(len(parameters)))
# np.random.seed(SEED)

# %%
del raw_train_diagrams
del raw_test_diagrams

# %%
import pickle

def load_vocab(filename='trained_embeddings.pkl'):
    with open(filename, 'rb') as f:
        loaded_dict = pickle.load(f)
#         loaded_dict['vocab'] = [Symbol(v) for v in loaded_dict['vocab']]
    return loaded_dict

embedding = load_vocab()

# %%
parameters = embedding['vocab']
weights = embedding['vals']

# %%
test_cost_fn, _, test_accs = make_cost_fn(test_pred_fn, test_labels)
test_cost_fn(weights)
print('Test accuracy:', test_accs[0])
# Out:
# Test accuracy: 0.6333333333333333

# %%
result = minimizeSPSA(train_cost_fn, x0=weights, a=0.2, c=0.06, niter=20)#, callback=dev_cost_fn)

# %%
import matplotlib.pyplot as plt
plt.plot(train_costs[1::2])
plt.title("Training")
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
embedding = {
    'vocab': parameters,
    'vals': list(result.x)
}
with open('trained_embeddings.pkl', 'wb') as f:
    pickle.dump(embedding, f)

# %%
result = minimizeSPSA(train_cost_fn, x0=result.x, a=0.2, c=0.06, niter=20, disp=True)

embedding = {
    'vocab': parameters,
    'vals': list(result.x)
}
with open('trained_embeddings.pkl', 'wb') as f:
    pickle.dump(embedding, f)
    
plt.plot(train_costs[1::2])
plt.title("Training")
plt.ylabel('Accuracy')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_2085/1198849719.py in <module>
# ----> 1 result = minimizeSPSA(train_cost_fn, x0=result.x, a=0.2, c=0.06, niter=20, disp=True)
#       2
#       3 embedding = {
#       4     'vocab': parameters,
#       5     'vals': list(result.x)
#
# ~/.local/lib/python3.8/site-packages/noisyopt/main.py in minimizeSPSA(func, x0, args, bounds, niter, paired, a, c, disp, callback)
#     326         x = project(x - ak*grad)
#     327         # print 100 status updates if disp=True
# --> 328         if disp and (k % (niter//100)) == 0:
#     329             print(x)
#     330         if callback is not None:
#
# ZeroDivisionError: integer division or modulo by zero

# %%
result = minimizeSPSA(train_cost_fn, x0=result.x, a=0.2, c=0.06, niter=20)

embedding = {
    'vocab': parameters,
    'vals': list(result.x)
}
with open('trained_embeddings.pkl', 'wb') as f:
    pickle.dump(embedding, f)
    
plt.plot(train_costs[1::2])
plt.title("Training")
plt.ylabel('Accuracy')

# %%
result = minimizeSPSA(train_cost_fn, x0=x0, a=0.2, c=0.06, niter=20)#, callback=dev_cost_fn)

# %%
import pickle
embedding = {
    'vocab': parameters,
    'vals': list(result.x)
}
with open('trained_embeddings.pkl', 'wb') as f:
    pickle.dump(embedding, f)

# %%
import matplotlib.pyplot as plt
plt.plot(train_costs[1::2])
plt.title("Training")
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
result = minimizeSPSA(train_cost_fn, x0=result.x, a=0.2, c=0.06, niter=20)
# Out:
# ---------------------------------------------------------------------------
# CircuitNotRunError                        Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pytket/extensions/qiskit/backends/aer.py in get_result(self, handle, **kwargs)
#     213         try:
# --> 214             return super().get_result(handle)
#     215         except CircuitNotRunError:
#
# ~/.local/lib/python3.8/site-packages/pytket/backends/backend.py in get_result(self, handle, **kwargs)
#     351             return cast(BackendResult, self._cache[handle]["result"])
# --> 352         raise CircuitNotRunError(handle)
#     353
#
# CircuitNotRunError: Circuit corresponding to ResultHandle('5608a73b-5c42-4c44-84d2-1158a247f0ef', 0) has not been run by this backend instance.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1485/2150566505.py in <module>
# ----> 1 result = minimizeSPSA(train_cost_fn, x0=result.x, a=0.2, c=0.06, niter=20)
#
# ~/.local/lib/python3.8/site-packages/noisyopt/main.py in minimizeSPSA(func, x0, args, bounds, niter, paired, a, c, disp, callback)
#     318             fkwargs['seed'] = np.random.randint(0, np.iinfo(np.uint32).max)
#     319         if bounds is None:
# --> 320             grad = (funcf(x + ck*delta, **fkwargs) - funcf(x - ck*delta, **fkwargs)) / (2*ck*delta)
#     321         else:
#     322             # ensure evaluation points are feasible
#
# ~/.local/lib/python3.8/site-packages/noisyopt/main.py in funcf(x, **kwargs)
#     306         # freeze function arguments
#     307         def funcf(x, **kwargs):
# --> 308             return func(x, *args, **kwargs)
#     309
#     310     N = len(x0)
#
# /tmp/ipykernel_1485/2702797892.py in cost_fn(params, **kwargs)
#       3 def make_cost_fn(pred_fn, labels):
#       4     def cost_fn(params, **kwargs):
# ----> 5         predictions = pred_fn(params)
#       6
#       7         cost = -np.sum(labels * np.log(predictions)) / len(labels)  # binary cross-entropy loss
#
# /tmp/ipykernel_1485/925553273.py in predict(params)
#      17
#      18     def predict(params):
# ---> 19         outputs = Circuit.eval(*(c_fn(*params) for c_fn in circuit_fns),
#      20                                **backend_config, seed=randint(rng))
#      21         return np.array([normalise(output.array) for output in outputs])
#
# ~/.local/lib/python3.8/site-packages/discopy/quantum/circuit.py in eval(self, backend, mixed, *others, **params)
#     272             return functor(self)
#     273         circuits = [circuit.to_tk() for circuit in (self, ) + others]
# --> 274         results, counts = [], circuits[0].get_counts(
#     275             *circuits[1:], backend=backend, **params)
#     276         for i, circuit in enumerate(circuits):
#
# ~/.local/lib/python3.8/site-packages/discopy/quantum/tk.py in get_counts(self, backend, *others, **params)
#     115         handles = backend.process_circuits(
#     116             (self, ) + others, n_shots=n_shots, seed=seed)
# --> 117         counts = [backend.get_result(h).get_counts() for h in handles]
#     118         if normalize:
#     119             counts = list(map(probs_from_counts, counts))
#
# ~/.local/lib/python3.8/site-packages/discopy/quantum/tk.py in <listcomp>(.0)
#     115         handles = backend.process_circuits(
#     116             (self, ) + others, n_shots=n_shots, seed=seed)
# --> 117         counts = [backend.get_result(h).get_counts() for h in handles]
#     118         if normalize:
#     119             counts = list(map(probs_from_counts, counts))
#
# ~/.local/lib/python3.8/site-packages/pytket/extensions/qiskit/backends/aer.py in get_result(self, handle, **kwargs)
#     220                 raise CircuitNotRunError(handle)
#     221
# --> 222             res = job.result()
#     223             backresults = qiskit_result_to_backendresult(res)
#     224             for circ_index, backres in enumerate(backresults):
#
# ~/.local/lib/python3.8/site-packages/qiskit/providers/aer/jobs/utils.py in _wrapper(self, *args, **kwargs)
#      38         if self._future is None:
#      39             raise JobError("Job not submitted yet!. You have to .submit() first!")
# ---> 40         return func(self, *args, **kwargs)
#      41     return _wrapper
#      42
#
# ~/.local/lib/python3.8/site-packages/qiskit/providers/aer/jobs/aerjob.py in result(self, timeout)
#      76             concurrent.futures.CancelledError: if job cancelled before completed.
#      77         """
# ---> 78         return self._future.result(timeout=timeout)
#      79
#      80     @requires_submit
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
import pickle
embedding = {
    'vocab': parameters,
    'vals': list(result.x)
}
with open('trained_embeddings.pkl', 'wb') as f:
    pickle.dump(embedding, f)
    
plt.plot(train_costs[1::2])
plt.title("Training")
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
result = minimizeSPSA(train_cost_fn, x0=result.x, a=0.2, c=0.06, niter=20)

embedding = {
    'vocab': parameters,
    'vals': list(result.x)
}
with open('trained_embeddings.pkl', 'wb') as f:
    pickle.dump(embedding, f)
    
plt.plot(train_costs[1::2])
plt.title("Training")
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
embedding = {
    'vocab': parameters,
    'vals': list(result.x)
}
with open('trained_embeddings.pkl', 'wb') as f:
    pickle.dump(embedding, f)

# %%
result = minimizeSPSA(train_cost_fn, x0=result.x, a=0.2, c=0.06, niter=20)

embedding = {
    'vocab': parameters,
    'vals': list(result.x)
}
with open('trained_embeddings.pkl', 'wb') as f:
    pickle.dump(embedding, f)
    
plt.plot(train_costs[1::2])
plt.title("Training")
plt.ylabel('Accuracy')
# Out:
# IOStream.flush timed out

# %%
result = minimizeSPSA(train_cost_fn, x0=result.x, a=0.2, c=0.06, niter=20)

embedding = {
    'vocab': parameters,
    'vals': list(result.x)
}
with open('trained_embeddings.pkl', 'wb') as f:
    pickle.dump(embedding, f)
    
plt.plot(train_costs[1::2])
plt.title("Training")
plt.ylabel('Accuracy')

# %% [markdown]
# ### Show results

# %%
import matplotlib.pyplot as plt

fig, ((ax_tl, ax_tr), (ax_bl, ax_br)) = plt.subplots(2, 2, sharex=True, sharey='row', figsize=(10, 6))
ax_tl.set_title('Training set')
ax_tr.set_title('Development set')
ax_bl.set_xlabel('Iterations')
ax_br.set_xlabel('Iterations')
ax_bl.set_ylabel('Accuracy')
ax_tl.set_ylabel('Loss')

colours = iter(plt.rcParams['axes.prop_cycle'].by_key()['color'])
ax_tl.plot(train_costs[1::2], color=next(colours))  # training evaluates twice per iteration
ax_bl.plot(train_accs[1::2], color=next(colours))   # so take every other entry
# ax_tr.plot(dev_costs, color=next(colours))
# ax_br.plot(dev_accs, color=next(colours))

# print test accuracy
test_cost_fn, _, test_accs = make_cost_fn(test_pred_fn, test_labels)
test_cost_fn(result.x)
print('Test accuracy:', test_accs[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_127/2076129089.py in <module>
#      17 # print test accuracy
#      18 test_cost_fn, _, test_accs = make_cost_fn(test_pred_fn, test_labels)
# ---> 19 test_cost_fn(result.x)
#      20 print('Test accuracy:', test_accs[0])
#
# /tmp/ipykernel_127/995170266.py in cost_fn(params, **kwargs)
#       3 def make_cost_fn(pred_fn, labels):
#       4     def cost_fn(params, **kwargs):
# ----> 5         predictions = pred_fn(params)
#       6
#       7         cost = -np.sum(labels * np.log(predictions)) / len(labels)  # binary cross-entropy loss
#
# /tmp/ipykernel_127/1914696841.py in predict(params)
#      17
#      18     def predict(params):
# ---> 19         outputs = Circuit.eval(*(c_fn(*params) for c_fn in circuit_fns),
#      20                                **backend_config, seed=randint(rng))
#      21         return np.array([normalise(output.array) for output in outputs])
#
# ~/.local/lib/python3.8/site-packages/discopy/quantum/circuit.py in eval(self, backend, mixed, *others, **params)
#     271                 else tensor.Functor(lambda x: x[0].dim, lambda f: f.array)
#     272             return functor(self)
# --> 273         circuits = [circuit.to_tk() for circuit in (self, ) + others]
#     274         results, counts = [], circuits[0].get_counts(
#     275             *circuits[1:], backend=backend, **params)
#
# ~/.local/lib/python3.8/site-packages/discopy/quantum/circuit.py in <listcomp>(.0)
#     271                 else tensor.Functor(lambda x: x[0].dim, lambda f: f.array)
#     272             return functor(self)
# --> 273         circuits = [circuit.to_tk() for circuit in (self, ) + others]
#     274         results, counts = [], circuits[0].get_counts(
#     275             *circuits[1:], backend=backend, **params)
#
# ~/.local/lib/python3.8/site-packages/discopy/quantum/circuit.py in to_tk(self)
#     412         # pylint: disable=import-outside-toplevel
#     413         from discopy.quantum.tk import to_tk
# --> 414         return to_tk(self)
#     415
#     416     @staticmethod
#
# ~/.local/lib/python3.8/site-packages/discopy/quantum/tk.py in to_tk(circuit)
#     142     # bits and qubits are lists of register indices, at layer i we want
#     143     # len(bits) == circuit[:i].cod.count(bit) and same for qubits
# --> 144     tk_circ, bits, qubits = Circuit(), [], []
#     145     circuit = circuit.init_and_discard()
#     146
#
# ~/.local/lib/python3.8/site-packages/discopy/quantum/tk.py in __init__(self, n_qubits, n_bits, post_selection, scalar, post_processing)
#      39         self.post_processing = post_processing\
#      40             or Id(bit ** (n_bits - len(self.post_selection)))
# ---> 41         super().__init__(n_qubits, n_bits)
#      42
#      43     def __repr__(self):
#
# KeyboardInterrupt:

# %%
# print test accuracy
test_cost_fn, _, test_accs = make_cost_fn(test_pred_fn, test_labels)
test_cost_fn(result.x)
print('Test accuracy:', test_accs[0])
# Out:
# Test accuracy: 0.9666666666666667

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.rand(20) * 10 - 5

# %%
fig, (ax_l, ax_r) = plt.subplots(1, 2, figsize=(12, 4), dpi=120)

# c1 = x[np.abs(x) < 2]
# c2 = x[~(np.abs(x) < 2)]

# ax_l.scatter(c1, np.zeros(len(c1)), c='b', label='Class 1')
# ax_l.scatter(c2, np.zeros(len(c2)), c='g', label='Class 2')

ax_l.plot(train_costs[1::2], c='g')#color=next(colours))  # training evaluates twice per iteration
ax_r.plot(train_accs[1::2], c='b')#color=next(colours))

ax_r.set_title("Training accuracy")
# ax_l.legend()
ax_r.set_xlabel("Iterations")
ax_r.set_ylabel("Accuuracy")
# ax_l.get_yaxis().set_ticks([])

# ax_r.scatter(c1, c1**2, c='b', label='Class 1')
# ax_r.scatter(c2, c2**2, c='g', label='Class 2')

ax_l.set_title("Training cost")
# ax_r.legend()
ax_l.set_xlabel("Iterations")
ax_l.set_ylabel("Cost")

fig

# %%
fig.savefig('replication-training_96-66-acc')

# %%
8192/2

# %%
train_accs
# Out:
# [0.45714285714285713,
#  0.5857142857142857,
#  0.6,
#  0.5714285714285714,
#  0.5714285714285714,
#  0.6571428571428571,
#  0.6857142857142857,
#  0.4928571428571429,
#  0.5285714285714286,
#  0.5642857142857143,
#  0.4142857142857143,
#  0.5,
#  0.4,
#  0.5285714285714286,
#  0.5428571428571428,
#  0.5571428571428572,
#  0.6285714285714286,
#  0.7142857142857143,
#  0.5,
#  0.4142857142857143,
#  0.5428571428571428,
#  0.4857142857142857,
#  0.6,
#  0.6428571428571429,
#  0.6142857142857143,
#  0.5285714285714286,
#  0.5785714285714286,
#  0.5714285714285714,
#  0.5714285714285714,
#  0.5285714285714286,
#  0.5857142857142857,
#  0.5285714285714286,
#  0.6,
#  0.6142857142857143,
#  0.5428571428571428,
#  0.6,
#  0.7,
#  0.6285714285714286,
#  0.5857142857142857,
#  0.6428571428571429,
#  0.5714285714285714,
#  0.6285714285714286,
#  0.5714285714285714,
#  0.6857142857142857,
#  0.5857142857142857,
#  0.6142857142857143,
#  0.6,
#  0.6,
#  0.5857142857142857,
#  0.6285714285714286,
#  0.6285714285714286,
#  0.5142857142857142,
#  0.7,
#  0.5857142857142857,
#  0.5857142857142857,
#  0.6142857142857143,
#  0.6,
#  0.5428571428571428,
#  0.5714285714285714,
#  0.7142857142857143,
#  0.5428571428571428,
#  0.6142857142857143,
#  0.5428571428571428,
#  0.5857142857142857,
#  0.5714285714285714,
#  0.5285714285714286,
#  0.6142857142857143,
#  0.5857142857142857,
#  0.6714285714285714,
#  0.5642857142857143,
#  0.6285714285714286,
#  0.6571428571428571,
#  0.6428571428571429,
#  0.6142857142857143,
#  0.5571428571428572,
#  0.6857142857142857,
#  0.6857142857142857,
#  0.6142857142857143,
#  0.6357142857142857,
#  0.6714285714285714,
#  0.7,
#  0.7285714285714285,
#  0.7,
#  0.7,
#  0.6428571428571429,
#  0.7142857142857143,
#  0.6285714285714286,
#  0.7,
#  0.6714285714285714,
#  0.7071428571428572,
#  0.7142857142857143,
#  0.7,
#  0.7142857142857143,
#  0.6857142857142857,
#  0.7142857142857143,
#  0.6714285714285714,
#  0.6714285714285714,
#  0.6857142857142857,
#  0.6785714285714286,
#  0.6857142857142857,
#  0.6714285714285714,
#  0.6428571428571429,
#  0.6857142857142857,
#  0.7142857142857143,
#  0.6571428571428571,
#  0.7,
#  0.6857142857142857,
#  0.75,
#  0.6857142857142857,
#  0.7142857142857143,
#  0.6857142857142857,
#  0.7,
#  0.6857142857142857,
#  0.7,
#  0.7,
#  0.6857142857142857,
#  0.7142857142857143,
#  0.7285714285714285,
#  0.7,
#  0.6857142857142857,
#  0.7285714285714285,
#  0.7142857142857143,
#  0.7142857142857143,
#  0.7285714285714285,
#  0.6142857142857143,
#  0.6857142857142857,
#  0.6571428571428571,
#  0.7428571428571429,
#  0.7,
#  0.7857142857142857,
#  0.7714285714285715,
#  0.7285714285714285,
#  0.7714285714285715,
#  0.7571428571428571,
#  0.7571428571428571,
#  0.7214285714285714,
#  0.7571428571428571,
#  0.7285714285714285,
#  0.7714285714285715,
#  0.7142857142857143,
#  0.7,
#  0.7571428571428571,
#  0.7857142857142857,
#  0.7285714285714285,
#  0.7428571428571429,
#  0.8714285714285714,
#  0.9,
#  0.7142857142857143,
#  0.7,
#  0.8428571428571429,
#  0.8857142857142857,
#  0.7285714285714285,
#  0.8285714285714286,
#  0.8285714285714286,
#  0.8857142857142857,
#  0.7857142857142857,
#  0.7571428571428571,
#  0.9714285714285714,
#  0.9142857142857143,
#  0.8,
#  0.8,
#  0.9428571428571428,
#  0.8857142857142857,
#  0.8785714285714286,
#  0.9,
#  0.8214285714285714,
#  0.7857142857142857,
#  0.9,
#  0.9428571428571428,
#  0.8714285714285714,
#  0.8857142857142857,
#  0.8857142857142857,
#  0.9714285714285714,
#  0.8857142857142857,
#  0.8714285714285714,
#  0.9,
#  0.9571428571428572,
#  0.9285714285714286,
#  0.9142857142857143,
#  0.9142857142857143,
#  0.9571428571428572,
#  0.9571428571428572,
#  0.9142857142857143,
#  0.9571428571428572,
#  0.9428571428571428,
#  0.9428571428571428,
#  0.9142857142857143,
#  0.9428571428571428,
#  0.9857142857142858,
#  0.9142857142857143,
#  0.9428571428571428,
#  0.9571428571428572,
#  0.9714285714285714,
#  0.9571428571428572,
#  0.9571428571428572,
#  0.9571428571428572,
#  0.9857142857142858,
#  0.9571428571428572,
#  0.9571428571428572,
#  0.9428571428571428,
#  0.9714285714285714]
